# %% [markdown]
# **Exploratory Data Analysis Mercado Livre**

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# The first step is the definition of the function that will fetch the data stored in the Mercado Livre public API.
#
# The product to be searched can be informed in the variable 'product'.

# %%
# Return the data in API
def search_data():
    # Connect with the public API, download the content in json format
    request = requests.get(f"https://api.mercadolibre.com/sites/MLB/search?q={product}")
    data = json.loads(request.content)

    return data

# %%
# Edit the variable product. Type the product to be researched, example: 'cofre', 'câmera de segurança', etc
product = "cofre"

# %%
# Store the data in json format
dataset = search_data()

# %% [markdown]
# **Investigating Data**
#
# In the following step the dataset is investigated. The data download from the API is represented in a dictionary that contains several data and metadata, which is not ready to infer statistics and needs to be pre-processed.
#
# The keys of the dictionary are evaluated in order to find which represents the most valuable data in terms of relevant information.
#
# Initially the key result is the first to represent good data insights.

# %%
print(dataset.keys())
# Out:
# dict_keys(['site_id', 'country_default_time_zone', 'query', 'paging', 'results', 'sort', 'available_sorts', 'filters', 'available_filters', 'pdp_tracking'])

# %%
print(len(dataset['results']))
# Out:
# 50

# %%
# Key 'results' dataframe
df = pd.DataFrame(dataset['results'])

# %%
df.head()
# Out:
#               id                                              title condition  \
# 0  MLB3059005282  Cofre Eletrônico Digital Em Aço Teclado Senha ...       new
# 1  MLB3377629545  Cofre Digital Eletrônico Grande 50cm Senha E C...       new
# 2  MLB3379152371  Cofre Eletrônico Grande Visor Digital Senha Pa...       new
# 3  MLB3049617790  Cofre Digital Eletrônico Para Armas Jóias Docu...       new
# 4  MLB3372390051  Cofre Eletrônico Digital Visor Lcd Teclado Sen...       new
#
#                    thumbnail_id catalog_product_id listing_type_id  \
# 0  878844-MLA52871550631_122022        MLB20692931    gold_special
# 1  970441-MLU72566189718_112023        MLB24472893    gold_special
# 2  783251-MLU72636986379_112023        MLB24549963    gold_special
# 3  688774-MLU74988940142_032024        MLB20222736    gold_special
# 4  741972-MLU72831732141_112023        MLB20794536    gold_special
#
#                                            permalink buying_mode site_id  \
# 0  https://www.mercadolivre.com.br/cofre-eletrnic...  buy_it_now     MLB
# 1  https://www.mercadolivre.com.br/cofre-digital-...  buy_it_now     MLB
# 2  https://www.mercadolivre.com.br/cofre-eletrnic...  buy_it_now     MLB
# 3  https://www.mercadolivre.com.br/cofre-digital-...  buy_it_now     MLB
# 4  https://www.mercadolivre.com.br/cofre-eletrnic...  buy_it_now     MLB
#
#   category_id  ...                                       installments  \
# 0    MLB33430  ...  {'quantity': 12, 'amount': 12.59, 'rate': 16.6...
# 1    MLB33430  ...  {'quantity': 12, 'amount': 55.65, 'rate': 16.3...
# 2    MLB33430  ...  {'quantity': 12, 'amount': 45.83, 'rate': 16.3...
# 3    MLB33430  ...  {'quantity': 12, 'amount': 20.89, 'rate': 16.6...
# 4    MLB33430  ...  {'quantity': 12, 'amount': 21.22, 'rate': 16.6...
#
#   winner_item_id catalog_listing  discounts  promotions  inventory_id  \
# 0           None            True       None          []     FRXY46302
# 1           None            True       None          []     ZOHW19162
# 2           None            True       None          []     FKXU13750
# 3           None            True       None          []     XHWM51306
# 4           None            True       None          []     WUKX66455
#
#   differential_pricing  official_store_name  variation_filters  \
# 0                  NaN                  NaN                NaN
# 1                  NaN                  NaN                NaN
# 2                  NaN                  NaN                NaN
# 3                  NaN                  NaN                NaN
# 4                  NaN                  NaN                NaN
#
#    variations_data
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# # **1. Investigation Columns**

# %% [markdown]
# In this step the daframe obtained from the API is investigated in order to find the columns which contain the most relevant information in terms of numeric and categorical values.
#
# The goal is to generate a clean data frame that will be performed an exploratory analysis.

# %%
# Unique types in condition
df['condition'].unique()
# Out:
# array(['new'], dtype=object)

# %%
# Unique types in catalog_listing
df['catalog_listing'].unique()
# Out:
# array([ True, False])

# %%
# Unique types in listing_type_id
df['listing_type_id'].unique()
# Out:
# array(['gold_special', 'gold_pro'], dtype=object)

# %%
# Unique types in buying_mode
df['buying_mode'].unique()
# Out:
# array(['buy_it_now'], dtype=object)

# %%
# Unique types in price
df['price'].unique()
# Out:
# array([ 129.52,  573.99,  472.69,  214.91,  218.31,  151.89,  594.99,
#         239.92,  497.46,  299.61,   76.53,  228.96,  108.  ,  114.61,
#         333.28,  309.9 ,  209.9 ,  117.  ,   85.9 ,  104.  ,  119.99,
#         117.8 ,   40.35,   60.97,   64.9 ,  141.5 ,   59.46,  204.9 ,
#         147.  ,   76.84,  406.99,  285.74,  129.99,  169.9 ,  182.  ,
#          78.98,   19.13,  447.  ,  799.9 ,  910.  ,  137.9 ,  959.9 ,
#        2013.9 ,  299.  ,  117.77,  279.9 ,  279.99,  199.92])

# %%
# Unique types in original_price
df['original_price'].unique()
# Out:
# array([ 179.9 ,  699.99,  599.99,  249.9 ,  239.9 ,  151.89,  299.9 ,
#         369.9 ,  119.99,  228.96,     nan,  124.  ,   67.  ,  314.  ,
#          22.9 , 1000.  , 2119.9 ,  150.99])

# %%
# Unique types in sale_price
df['sale_price'].unique()
# Out:
# array([None], dtype=object)

# %%
# Unique types in sale_price
df['available_quantity'].unique()
# Out:
# array([ 500,    1,   50,  100,  200,  150,  250, 5000])

# %%
# Each item of the shipping column has a dictionary embedded
df['shipping'][0]
# Out:
# {'store_pick_up': False,
#  'free_shipping': True,
#  'logistic_type': 'fulfillment',
#  'mode': 'me2',
#  'tags': ['fulfillment', 'self_service_in', 'mandatory_free_shipping'],
#  'benefits': None,
#  'promise': None,
#  'shipping_score': -1}

# %%
# Unique types in stop_time
df['stop_time'].unique()
# Out:
# array(['2042-12-10T04:00:00.000Z', '2043-07-09T04:00:00.000Z',
#        '2044-05-11T20:53:08.000Z', '2042-12-07T04:00:00.000Z',
#        '2043-07-05T04:00:00.000Z', '2043-07-07T04:00:00.000Z',
#        '2044-02-19T16:09:53.000Z', '2044-05-05T15:20:19.000Z',
#        '2044-03-19T04:00:00.000Z', '2043-07-23T04:00:00.000Z',
#        '2043-12-28T04:00:00.000Z', '2043-06-19T04:00:00.000Z',
#        '2044-01-31T04:00:00.000Z', '2042-12-16T04:00:00.000Z',
#        '2042-02-10T04:00:00.000Z', '2041-08-28T04:00:00.000Z',
#        '2043-05-10T04:00:00.000Z', '2044-03-31T04:00:00.000Z',
#        '2044-05-19T04:00:00.000Z', '2043-12-16T04:00:00.000Z',
#        '2044-04-28T00:26:37.000Z', '2044-03-03T13:30:43.000Z',
#        '2044-05-12T04:00:00.000Z', '2044-05-16T04:00:00.000Z',
#        '2043-08-31T04:00:00.000Z', '2044-03-24T17:06:30.000Z',
#        '2044-04-11T13:33:12.000Z', '2043-11-11T04:00:00.000Z',
#        '2044-03-20T15:45:02.000Z', '2044-05-12T13:13:23.000Z',
#        '2044-02-01T04:00:00.000Z', '2044-02-06T04:00:00.000Z',
#        '2044-03-22T04:00:00.000Z', '2042-11-17T10:53:18.000Z',
#        '2044-02-12T04:00:00.000Z', '2044-02-11T04:00:00.000Z',
#        '2044-01-06T04:00:00.000Z', '2043-03-11T04:00:00.000Z',
#        '2043-01-01T04:00:00.000Z', '2043-05-25T04:00:00.000Z',
#        '2044-01-18T04:00:00.000Z', '2044-02-21T04:00:00.000Z',
#        '2044-02-29T04:00:00.000Z', '2044-02-25T04:00:00.000Z',
#        '2044-02-23T04:00:00.000Z', '2043-03-14T04:00:00.000Z'],
#       dtype=object)

# %% [markdown]
# The column installments contain a dictionary in each element. This column is transformed into a new dataframe.

# %%
installments = pd.DataFrame(dict(df['installments']))

# %%
installments = installments.transpose()

# %%
installments.shape
# Out:
# (50, 4)

# %%
installments.head()
# Out:
#   quantity amount   rate currency_id
# 0       12  12.59  16.64         BRL
# 1       12  55.65  16.34         BRL
# 2       12  45.83  16.34         BRL
# 3       12  20.89  16.64         BRL
# 4       12  21.22  16.64         BRL

# %%
installments.drop(["currency_id"],axis='columns', inplace=True)

# %%
installments.head()
# Out:
#   quantity amount   rate
# 0       12  12.59  16.64
# 1       12  55.65  16.34
# 2       12  45.83  16.34
# 3       12  20.89  16.64
# 4       12  21.22  16.64

# %% [markdown]
# # **2. New Data Frame**

# %% [markdown]
# In this step a new data frame is built with the most relevant columns for an exploratory data analysis.
#
# Each column is scrutinized in order to find essential information. Some columns have dictionaries embedded in each row, so it is necessary to take a look and gather all essential the information in a new dataframe.

# %%
# Dropping not essential columns
df.drop(["condition","thumbnail_id", "catalog_product_id","listing_type_id","permalink", "buying_mode", "installments", "winner_item_id",
"discounts", "promotions", "inventory_id", "differential_pricing", "official_store_name", "variation_filters", "variations_data"],axis='columns', inplace=True)

# %%
df.head(1)
# Out:
#               id                                              title site_id  \
# 0  MLB3059005282  Cofre Eletrônico Digital Em Aço Teclado Senha ...     MLB
#
#   category_id  domain_id                                          thumbnail  \
# 0    MLB33430  MLB-SAFES  http://http2.mlstatic.com/D_878844-MLA52871550...
#
#   currency_id  order_backend   price  original_price sale_price  \
# 0         BRL              1  129.52           179.9       None
#
#    available_quantity  official_store_id  use_thumbnail_id  \
# 0                 500                NaN              True
#
#    accepts_mercadopago                                           shipping  \
# 0                 True  {'store_pick_up': False, 'free_shipping': True...
#
#                   stop_time                                         seller  \
# 0  2042-12-10T04:00:00.000Z  {'id': 1121312484, 'nickname': 'CLASP STORE'}
#
#                                           attributes  catalog_listing
# 0  [{'id': 'BRAND', 'name': 'Marca', 'value_id': ...             True

# %%
# New dataframe from the column sellers
sellers = pd.DataFrame(dict(df["seller"]))
sellers = sellers.transpose()

# %%
sellers.head()
# Out:
#            id      nickname
# 0  1121312484   CLASP STORE
# 1   789812463   VERONA SHOP
# 2  1249889840  MAIKO_BRASIL
# 3  1121312484   CLASP STORE
# 4   789812463   VERONA SHOP

# %%
# New dataframe from the column attributes, seleting the brand's name
brands ={
    "brand": []
}

for i in range(len(df["attributes"])):
  #print(df["attributes"][i][0]['value_name'])
  brands["brand"].append(df["attributes"][i][0]['value_name'])

brands = pd.DataFrame(brands)
brands.head()
# Out:
#     brand
# 0  Forkis
# 1  Forkis
# 2  Forkis
# 3  Forkis
# 4  Forkis

# %%
# Dropping new other columns
df.drop(["site_id","category_id","domain_id","thumbnail","currency_id","order_backend","official_store_id","use_thumbnail_id","accepts_mercadopago",
"shipping","seller","attributes","sale_price"],axis='columns', inplace=True)

# %%
df["brand"] = brands['brand']

# %%
df["seller"] = sellers["nickname"]

# %%
df.head(2)
# Out:
#               id                                              title   price  \
# 0  MLB3059005282  Cofre Eletrônico Digital Em Aço Teclado Senha ...  129.52
# 1  MLB3377629545  Cofre Digital Eletrônico Grande 50cm Senha E C...  573.99
#
#    original_price  available_quantity                 stop_time  \
# 0          179.90                 500  2042-12-10T04:00:00.000Z
# 1          699.99                   1  2043-07-09T04:00:00.000Z
#
#    catalog_listing   brand       seller
# 0             True  Forkis  CLASP STORE
# 1             True  Forkis  VERONA SHOP

# %% [markdown]
# **Final dataframe**

# %%
# Definitive data frame
data = pd.concat([df,installments],axis=1)
data.head(2)
# Out:
#               id                                              title   price  \
# 0  MLB3059005282  Cofre Eletrônico Digital Em Aço Teclado Senha ...  129.52
# 1  MLB3377629545  Cofre Digital Eletrônico Grande 50cm Senha E C...  573.99
#
#    original_price  available_quantity                 stop_time  \
# 0          179.90                 500  2042-12-10T04:00:00.000Z
# 1          699.99                   1  2043-07-09T04:00:00.000Z
#
#    catalog_listing   brand       seller quantity amount   rate
# 0             True  Forkis  CLASP STORE       12  12.59  16.64
# 1             True  Forkis  VERONA SHOP       12  55.65  16.34

# %% [markdown]
# # **3. Exploratory Analysis**

# %%
# Number of rows and columns
data.shape
# Out:
# (50, 12)

# %%
# Gathering data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  50 non-null     object
#  1   title               50 non-null     object
#  2   price               50 non-null     float64
#  3   original_price      22 non-null     float64
#  4   available_quantity  50 non-null     int64
#  5   stop_time           50 non-null     object
#  6   catalog_listing     50 non-null     bool
#  7   brand               50 non-null     object
#  8   seller              50 non-null     object
#  9   quantity            47 non-null     object
#  10  amount              47 non-null     object
#  11  rate                47 non-null     object
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 4.5+ KB

# %% [markdown]
# Changing data type of values in int64,float 64 to int32, float32

# %%
data["price"] = (data["price"].astype("float32")).apply(lambda x: round(x, 2))
data["original_price"] = (data["original_price"].astype("float32")).apply(lambda x: round(x, 2))
data["available_quantity"] =  data["available_quantity"].astype("int32")

# %%
# Count missing values in relevant columns
data.isna().sum(axis = 0)
# Out:
# id                     0
# title                  0
# price                  0
# original_price        28
# available_quantity     0
# stop_time              0
# catalog_listing        0
# brand                  0
# seller                 0
# quantity               3
# amount                 3
# rate                   3
# dtype: int64

# %%
# Replacing missing values with the element that appers the most in the table
data["quantity"] = data["quantity"].fillna("10")

# %%
# Replacing missing values with the mean
data["amount"] = data["amount"].fillna(data["amount"].mean())

# %%
data["rate"] = data["rate"].fillna(data["rate"].mean())

# %%
# Changing data types of columns in the object format to int and float
data["quantity"] = data["quantity"].astype("int32")
data["amount"] = data["amount"].astype("float32")
data["rate"] = data["rate"].astype("float32")

# %%
# Gathering data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  50 non-null     object
#  1   title               50 non-null     object
#  2   price               50 non-null     float64
#  3   original_price      22 non-null     float64
#  4   available_quantity  50 non-null     int32
#  5   stop_time           50 non-null     object
#  6   catalog_listing     50 non-null     bool
#  7   brand               50 non-null     object
#  8   seller              50 non-null     object
#  9   quantity            50 non-null     int32
#  10  amount              50 non-null     float32
#  11  rate                50 non-null     float32
# dtypes: bool(1), float32(2), float64(2), int32(2), object(5)
# memory usage: 3.7+ KB

# %% [markdown]
# Taking a look at some categorical columns

# %%
# Top brands
data.value_counts("brand")
# Out:
# brand
# Forkis           9
# Cofres Lozano    4
# Contelux         4
# Fercar           3
# Animo Shop       3
# Ordene           2
# Lorben           2
# Unyhome          2
# Safewell         2
# PCI Eletro       2
# Oria             2
# Yale             2
# Getwell          2
# Genérica         1
# Fixser           1
# Preto            1
# SH               1
# DME              1
# Tssaper          1
# CCS              1
# Vaultz           1
# Western          1
# Xsafe            1
# ACCAFT           1
# Name: count, dtype: int64

# %%
# Top sellers
data.value_counts("seller")
# Out:
# seller
# CLASP STORE                 6
# COFRESLOZANO                4
# SELLOR DISTRIBUIDORA        3
# CONTELUX                    3
# VERONA SHOP                 2
# NEBRASKA PARTS              2
# LORBEN_OFICIAL              2
# DUBAI.IMPORTADORA SP        2
# ELETROEXPRESS-ML            2
# PERFETTO IMPORTS            1
# MARCOS_DOS_SANTOS_JUNIOR    1
# MEGA ALFA                   1
# PABER.                      1
# SAFEWELL OFICIAL            1
# RENOIMPORTS                 1
# SHINE062                    1
# TONGOU                      1
# TOY SHOPPETS                1
# MAIKO_BRASIL                1
# ACCAFT DISTRIBUIDORA        1
# LOJA MIXX                   1
# JR2X                        1
# ANIMO SHOP                  1
# IMPRESSORAJATO.COM.BR       1
# GSJ SANTOS                  1
# FLYSEA                      1
# FASTBRAS IMPORT             1
# DAMVIX                      1
# CONCEPTONEOFICIAL           1
# CASAGOLDEN OFICIAL          1
# BF IMPORTS23                1
# BAGI7124038                 1
# INOVARMETAIS                1
# Name: count, dtype: int64

# %% [markdown]
# Describing numerical columns

# %%
data.describe()
# Out:
#              price  original_price  available_quantity   quantity      amount  \
# count    50.000000       22.000000           50.000000  50.000000   50.000000
# mean    277.425000      392.490455          174.680000  10.560000   31.377022
# std     331.405303      468.490712          711.629043   2.921839   31.780525
# min      19.130000       22.900000            1.000000   3.000000    3.910000
# 25%     109.652500      130.747500            1.000000  10.000000   13.885000
# 50%     175.950000      244.900000            1.000000  12.000000   23.320000
# 75%     299.457500      542.467500           87.500000  12.000000   34.334999
# max    2013.900000     2119.900000         5000.000000  12.000000  201.389999
#
#             rate
# count  50.000000
# mean   10.557446
# std     7.784263
# min     0.000000
# 25%     0.000000
# 50%    16.340000
# 75%    16.639999
# max    16.639999

# %% [markdown]
# # **4. Visualizing Data**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(data=data, x="brand", y="price")
plt.xlabel("Brand")
plt.xticks(rotation=60)
plt.ylabel("Price")
plt.title("Brand and their Average Price")
plt.show()
